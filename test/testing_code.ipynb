# %%
import sys
import os

# Get the current working directory (where the notebook is running from)
current_dir = os.getcwd()
# Get the path to the 'nave_visualization' folder (the root folder)
project_root = os.path.abspath(os.path.join(current_dir, '..'))
project_root = project_root + "\\" +"nave_visualization_core\\"


# Add the path to 'nave_visualization' to sys.path
sys.path.append(project_root)


import vis_functions as nave

# %%
input_path = current_dir + "\\" + "71b0fde7-51f8-4df1-9b95-930dfe1af6de"

# %%
granule = nave.create_granule_dict(input_path)

# %%
granule
# Out:
# {'btm1_block': <xarray.Dataset>
#  Dimensions:          (time: 136, lat: 9, lon: 12, depth: 6)
#  Coordinates:
#    * time             (time) datetime64[ns] 2024-05-27 2024-05-28 ... 2024-10-09
#    * lat              (lat) float64 41.17 41.17 41.17 41.17 ... 41.16 41.16 41.16
#    * lon              (lon) float64 -96.48 -96.48 -96.48 ... -96.47 -96.47 -96.47
#    * depth            (depth) int64 5 15 30 60 100 200
#  Data variables: (12/15)
#      trnsp            (time, lat, lon) float64 ...
#      rtzn_dp          (time, lat, lon) float32 ...
#      wshort_risk      (time, lat, lon) float64 ...
#      wexcess_risk     (time, lat, lon) float64 ...
#      sm_05_cm_est     (time, lat, lon) float64 ...
#      sm_05_cm_sgm     (time, lat, lon) float64 ...
#      ...               ...
#      sm_30_cm_sgm     (time, lat, lon) float64 ...
#      sm_60_cm_est     (time, lat, lon) float64 ...
#      sm_60_cm_sgm     (time, lat, lon) float64 ...
#      assim_rz_sm_est  (time, lat, lon) float64 ...
#      assim_rz_sm_sgm  (time, lat, lon) float64 ...
#      wlp              (time, lat, lon) float64 ...
#  Attributes: (12/20)
#      field_GUID:                      71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      aoi:                             POLYGON ((-96.48263919532461 41.16555682...
#      crop:                            corn
#      uid:                             71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      Curent_rzsm_mm:                  266.990428427426
#      Current_rzsm_risk_category:      0
#      ...                              ...
#      Forecast_wexcess_risk_perc:      0.8768157834052062
#      Forecast_wexcess_risk_category:  0
#      Forecast_transit_date:           2024-10-01
#      Crop_type:                       corn
#      field_uid:                       71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      NPV:                             NAVE-BTM_V2.0,
#  'wth1_block': <xarray.Dataset>
#  Dimensions:       (longitude: 1, latitude: 1, time: 137)
#  Coordinates:
#    * longitude     (longitude) float64 -96.48
#    * latitude      (latitude) float64 41.17
#    * time          (time) datetime64[ns] 2024-05-26 2024-05-27 ... 2024-10-09
#  Data variables:
#      ETo_mm_d      (time, longitude, latitude) float64 ...
#      Tdk_max       (time, longitude, latitude) float64 ...
#      Tdk_min       (time, longitude, latitude) float64 ...
#      Insol_MJ_d    (time, longitude, latitude) float32 ...
#      Precip_m_d    (time, longitude, latitude) float64 ...
#      RHd_max       (time, longitude, latitude) float64 ...
#      RHd_min       (time, longitude, latitude) float64 ...
#      Wd_max        (time, longitude, latitude) float64 ...
#      Wd_min        (time, longitude, latitude) float64 ...
#      irrigtn_mm_d  (time, longitude, latitude) float64 ...
#  Attributes:
#      Forecast_transit_date:          2024-10-01
#      uid:                            71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      aoi:                            POLYGON ((-96.48263919532461 41.165556829...
#      crop:                           corn
#      Forecast_precip_mm_week:        0.6000000000000001
#      Forecast_precip_risk_category:  0
#      Days_since_last_irrigation:     129
#      Days_since_last_rain:           9
#      Latitude:                       41.165196
#      Longitude:                      -96.477927
#      field_uid:                      71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      NPV:                            Meteomatics_via_EOSDA,
#  'twr1_block': <xarray.Dataset>
#  Dimensions:         (time: 137, lat: 9, lon: 12)
#  Coordinates:
#    * time            (time) datetime64[ns] 2024-05-26 2024-05-27 ... 2024-10-09
#    * lat             (lat) float64 41.17 41.17 41.17 41.17 ... 41.16 41.16 41.16
#    * lon             (lon) float64 -96.48 -96.48 -96.48 ... -96.47 -96.47 -96.47
#  Data variables:
#      KC              (time, lat, lon) float32 ...
#      LAI             (time, lat, lon) float32 ...
#      AWL             (time, lat, lon) float32 ...
#      ETA_est_mm_day  (time, lat, lon) float32 ...
#      ETA_sgm_mm_day  (time, lat, lon) float32 ...
#      irrigtn_mm_d    (time, lat, lon) float32 ...
#      Fr_Cover        (time, lat, lon) float32 ...
#  Attributes:
#      Forecast_transit_date:      2024-10-01
#      uid:                        71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      aoi:                        POLYGON ((-96.48263919532461 41.1655568294038...
#      crop:                       corn
#      Curent_et_mm_day:           0.24968673
#      Current_et_risk_category:   0
#      Forecast_et_mm_day:         0.15293607
#      Forecast_et_risk_category:  0
#      Crop_type:                  corn
#      field_uid:                  71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      NPV:                        NAVE-TOP_V1.3,
#  'thr1_block': <xarray.Dataset>
#  Dimensions:  (time: 137, lat: 88, lon: 145)
#  Coordinates:
#    * time     (time) datetime64[ns] 2024-05-26 2024-05-27 ... 2024-10-09
#    * lat      (lat) float64 41.17 41.17 41.17 41.17 ... 41.16 41.16 41.16 41.16
#    * lon      (lon) float64 -96.48 -96.48 -96.48 -96.48 ... -96.47 -96.47 -96.47
#  Data variables:
#      LAI      (time, lat, lon) float64 ...
#  Attributes:
#      units:                  m2/m2
#      Forecast_transit_date:  2024-10-01
#      uid:                    71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      aoi:                    POLYGON ((-96.48263919532461 41.165556829403855, ...
#      crop:                   corn
#      Crop_type:              corn
#      field_uid:              71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      NPV:                    NAVE-TOP_V1.3,
#  'soi1_block': <xarray.Dataset>
#  Dimensions:  (depth: 6, lat: 9, lon: 12)
#  Coordinates:
#    * lon      (lon) float64 -96.48 -96.48 -96.48 -96.48 ... -96.47 -96.47 -96.47
#    * lat      (lat) float64 41.17 41.17 41.17 41.17 41.16 41.16 41.16 41.16 41.16
#    * depth    (depth) int64 5 15 30 60 100 200
#  Data variables:
#      clay     (depth, lat, lon) float64 ...
#      silt     (depth, lat, lon) float64 ...
#      sand     (depth, lat, lon) float64 ...
#      om       (depth, lat, lon) float64 ...
#      wp       (depth, lat, lon) float64 ...
#      fhc      (depth, lat, lon) float64 ...
#  Attributes:
#      field_GUID:  71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      aoi:         POLYGON ((-96.48263919532461 41.165556829403855, -96.4822050...
#      crop:        corn
#      field_uid:   71b0fde7-51f8-4df1-9b95-930dfe1af6de
#      NPV:         NAVE-BTM_V2.0,
#  'btm1_path': 'C:\\Users\\nicsw\\Documents\\Nave_Projects\\nave_visualization\\test\\71b0fde7-51f8-4df1-9b95-930dfe1af6de\\FBTM_71b0fde7-51f8-4df1-9b95-930dfe1af6de_2024-10-07_83027.171601_WRes.nc',
#  'wth1_path': 'C:\\Users\\nicsw\\Documents\\Nave_Projects\\nave_visualization\\test\\71b0fde7-51f8-4df1-9b95-930dfe1af6de\\FW1D_71b0fde7-51f8-4df1-9b95-930dfe1af6de_2024-10-07_83027.201264.nc',
#  'twr1_path': 'C:\\Users\\nicsw\\Documents\\Nave_Projects\\nave_visualization\\test\\71b0fde7-51f8-4df1-9b95-930dfe1af6de\\FTOP_71b0fde7-51f8-4df1-9b95-930dfe1af6de_2024-10-07_83027.171601_WRes.nc',
#  'thr1_path': 'C:\\Users\\nicsw\\Documents\\Nave_Projects\\nave_visualization\\test\\71b0fde7-51f8-4df1-9b95-930dfe1af6de\\FTOP_71b0fde7-51f8-4df1-9b95-930dfe1af6de_2024-10-07_83027.180368_HRes.nc',
#  'soi1_path': 'C:\\Users\\nicsw\\Documents\\Nave_Projects\\nave_visualization\\test\\71b0fde7-51f8-4df1-9b95-930dfe1af6de\\SGR250_71b0fde7-51f8-4df1-9b95-930dfe1af6de_2024-10-07_83027.171601_WRes.nc'}

# %%
output_path = current_dir + "\\" + "demo_outputs"
print(output_path)
# Out:
# C:\Users\nicsw\Documents\Nave_Projects\nave_visualization\test\demo_outputs

# %%
nave.build_evapotranspiration_map(granule['twr1_block'], f"{output_path}\\evapotranspiration_map.pdf")

# %%
nave.build_leaching_map(granule['btm1_block'], f"{output_path}\\leaching_map.pdf")

# %%
nave.build_precip_irri_map(granule['wth1_block'], granule['twr1_block'], f"{output_path}\\precip_bar_chart.pdf")

# %%
nave.et_time_series_with_sigmas(granule['twr1_block'], f"{output_path}\\et_time_series.pdf")

# %%
nave.field_health_pdf_page('2024-06-01', granule['thr1_block'], f"{output_path}\\field_health_page.pdf")

# %%
nave.leaching_risk_page('2024-06-01', granule['btm1_block'], f"{output_path}\\leaching_page.pdf")

# %%
nave.drought_page('2024-06-01', granule['btm1_block'], f"{output_path}\\drought_page.pdf")

# %%
nave.soil_moisture_weekly('2024-06-01', granule['btm1_block'], f"{output_path}\\soil_moisture_weekly_page.pdf")

# %%
nave.crop_water_use_maps_page('2024-06-01', granule['twr1_block'], f"{output_path}\\crop_water_use_page.pdf")
